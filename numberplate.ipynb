# %%
pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: torchvision>=0.5 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (0.16.2)
# Requirement already satisfied: opencv-python-headless in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (1.12.0)
# Requirement already satisfied: numpy in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (1.26.3)
# Requirement already satisfied: Pillow in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (10.2.0)
# Requirement already satisfied: scikit-image in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (0.22.0)
# Requirement already satisfied: python-bidi in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (2.0.2)
# Requirement already satisfied: pyclipper in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: filelock in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from torch->easyocr) (2023.12.2)
# Requirement already satisfied: six in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from scikit-image->easyocr) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from scikit-image->easyocr) (2023.12.9)
# Requirement already satisfied: packaging>=21 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from scikit-image->easyocr) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from jinja2->torch->easyocr) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in c:\users\max\desktop\ipprojects\numberplate\im4\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\MAX\Desktop\IPProjects\numberplate\IM4\Scripts\python.exe -m pip install --upgrade pip

# %%
import cv2
import easyocr
from matplotlib import pyplot as plt

# %%
def preprocess_image(image_path):
    # Load the image
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise and improve OCR accuracy
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    return blurred

# %%
def perform_ocr(image, reader):
    # Perform OCR on the preprocessed image
    result = reader.readtext(image)

    # Extract and return the recognized text
    recognized_text = ' '.join([entry[1] for entry in result])
    return recognized_text

# %%
def display_image_with_results(image, recognized_text):
    # Display the image with recognized text
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(f"Recognized Text: {recognized_text}")
    plt.axis('off')
    plt.show()

# %%
def number_plate_recognition(image_path):
    # Preprocess the image
    preprocessed_image = preprocess_image(image_path)

    # Create an OCR reader using the 'en' language for English text
    reader = easyocr.Reader(['en'])

    # Perform OCR on the preprocessed image
    recognized_text = perform_ocr(preprocessed_image, reader)

    # Display the results
    display_image_with_results(cv2.imread(image_path), recognized_text)

# %%
# Example usage
image_path = r'C:\Users\MAX\Desktop\IPProjects\numberplate\IM4\plate1.jpg'
number_plate_recognition(image_path)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
